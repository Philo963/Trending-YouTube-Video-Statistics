# %% [markdown]
# # **Knowing Data**

# %%
# @title Knowing Data {"display-mode":"form"}
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
pd.set_option('display.max_columns', 200)

# %%
# Load CA data
df = pd.read_csv('CAvideos.csv')
# Load US data
df1 = pd.read_csv('USvideos.csv')

# %%
# prompt: print ETFs data and Mutual Funds data

print(df)
# Out:
#           video_id trending_date  \
# 0      n1WpP7iowLc      17.14.11
# 1      0dBIkQ4Mz1M      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      d380meD0W0M      17.14.11
# 4      2Vv-BfVoq4g      17.14.11
# ...            ...           ...
# 40876  sGolxsMSGfQ      18.14.06
# 40877  8HNuRNi8t70      18.14.06
# 40878  GWlKEM3m2EE      18.14.06
# 40879  lbMKLzQ4cNQ      18.14.06
# 40880  POTgw38-m58      18.14.06
#
#                                                    title     channel_title  \
# 0             Eminem - Walk On Water (Audio) ft. Beyoncé        EminemVEVO
# 1                          PLUSH - Bad Unboxing Fan Mail         iDubbbzTV
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...      Rudy Mancuso
# 3                               I Dare You: GOING BALD!?          nigahiga
# 4            Ed Sheeran - Perfect (Official Music Video)        Ed Sheeran
# ...                                                  ...               ...
# ...

# %%
# prompt: print ETFs data and Mutual Funds data

print(df1)
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      1ZAPwfrtAFY      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      puqaWrEC7tY      17.14.11
# 4      d380meD0W0M      17.14.11
# ...            ...           ...
# 40944  BZt0qjTWNhw      18.14.06
# 40945  1h7KV2sjUWY      18.14.06
# 40946  D6Oy4LfoqsU      18.14.06
# 40947  oV0zkMe1K8s      18.14.06
# 40948  ooyjaVdt-jA      18.14.06
#
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 40944                       The Cat Who Caught the Laser
# 40945                         True Facts : Ant Mutualism
# ...

# %%
# tells more about the data (rows/columns)
df.shape
# Out:
# (40881, 16)

# %%
df1.shape
# Out:
# (40949, 16)

# %%
df.head(10)
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
# 5  0yIWz1XEeyc      17.14.11
# 6  _uM5kFfkhB8      17.14.11
# 7  2kyS6SvSYSE      17.14.11
# 8  JzCsM1vtn78      17.14.11
# 9  43sm-QwLcx4      17.14.11
#
#                                                title     channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé        EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail         iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...      Rudy Mancuso
# 3                           I Dare You: GOING BALD!?          nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)        Ed Sheeran
# 5  Jake Paul Says Alissa Violet CHEATED with LOGA...        DramaAlert
# 6             Vanoss Superhero School - New Students      VanossGaming
# ...

# %%
df1.head(10)
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
# 5  gHZ1Qz0KiKM      17.14.11
# 6  39idVpFF7NQ      17.14.11
# 7  nc99ccSXST0      17.14.11
# 8  jr9QtXwC9vc      17.14.11
# 9  TUmyygCMMGA      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
# 5                              2 Weeks with iPhone X               iJustine
# 6          Roy Moore & Jeff Sessions Cold Open - SNL    Saturday Night Live
# ...

# %%
df.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
df.dtypes
# Out:
# video_id                  object
# trending_date             object
# title                     object
# channel_title             object
# category_id                int64
# publish_time              object
# tags                      object
# views                      int64
# likes                      int64
# dislikes                   int64
# comment_count              int64
# thumbnail_link            object
# comments_disabled           bool
# ratings_disabled            bool
# video_error_or_removed      bool
# description               object
# dtype: object

# %%
df1.dtypes
# Out:
# video_id                  object
# trending_date             object
# title                     object
# channel_title             object
# category_id                int64
# publish_time              object
# tags                      object
# views                      int64
# likes                      int64
# dislikes                   int64
# comment_count              int64
# thumbnail_link            object
# comments_disabled           bool
# ratings_disabled            bool
# video_error_or_removed      bool
# description               object
# dtype: object

# %%
df.describe()
# Out:
#         category_id         views         likes      dislikes  comment_count
# count  40881.000000  4.088100e+04  4.088100e+04  4.088100e+04   4.088100e+04
# mean      20.795553  1.147036e+06  3.958269e+04  2.009195e+03   5.042975e+03
# std        6.775054  3.390913e+06  1.326895e+05  1.900837e+04   2.157902e+04
# min        1.000000  7.330000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       20.000000  1.439020e+05  2.191000e+03  9.900000e+01   4.170000e+02
# 50%       24.000000  3.712040e+05  8.780000e+03  3.030000e+02   1.301000e+03
# 75%       24.000000  9.633020e+05  2.871700e+04  9.500000e+02   3.713000e+03
# max       43.000000  1.378431e+08  5.053338e+06  1.602383e+06   1.114800e+06

# %%
df1.describe()
# Out:
#         category_id         views         likes      dislikes  comment_count
# count  40949.000000  4.094900e+04  4.094900e+04  4.094900e+04   4.094900e+04
# mean      19.972429  2.360785e+06  7.426670e+04  3.711401e+03   8.446804e+03
# std        7.568327  7.394114e+06  2.288853e+05  2.902971e+04   3.743049e+04
# min        1.000000  5.490000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       17.000000  2.423290e+05  5.424000e+03  2.020000e+02   6.140000e+02
# 50%       24.000000  6.818610e+05  1.809100e+04  6.310000e+02   1.856000e+03
# 75%       25.000000  1.823157e+06  5.541700e+04  1.938000e+03   5.755000e+03
# max       43.000000  2.252119e+08  5.613827e+06  1.674420e+06   1.361580e+06

# %%
summary_stats = df.agg({
    'views': ['mean', 'median', 'min', 'max'],
    'likes': ['mean', 'median', 'min', 'max'],
    # Add other relevant columns as necessary
})
print(summary_stats)
# Out:
#                views         likes
# mean    1.147036e+06  3.958269e+04
# median  3.712040e+05  8.780000e+03
# min     7.330000e+02  0.000000e+00
# max     1.378431e+08  5.053338e+06

# %%
# Calculate summary statistics for relevant YouTube video statistics
summary_stats = df.agg({
    'views': ['mean', 'median', 'min', 'max'],
    'likes': ['mean', 'median', 'min', 'max'],
    'dislikes': ['mean', 'median', 'min', 'max'],
    'comment_count': ['mean', 'median', 'min', 'max']
})

print(summary_stats)
# Out:
#                views         likes      dislikes  comment_count
# mean    1.147036e+06  3.958269e+04  2.009195e+03   5.042975e+03
# median  3.712040e+05  8.780000e+03  3.030000e+02   1.301000e+03
# min     7.330000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# max     1.378431e+08  5.053338e+06  1.602383e+06   1.114800e+06

# %% [markdown]
# # **Data Preparation**

# %%
df.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
print(df.isnull().sum())
# Out:
# video_id                     0
# trending_date                0
# title                        0
# channel_title                0
# category_id                  0
# publish_time                 0
# tags                         0
# views                        0
# likes                        0
# dislikes                     0
# comment_count                0
# thumbnail_link               0
# comments_disabled            0
# ratings_disabled             0
# video_error_or_removed       0
# description               1296
# dtype: int64

# %%
print(df1.isnull().sum())
# Out:
# video_id                    0
# trending_date               0
# title                       0
# channel_title               0
# category_id                 0
# publish_time                0
# tags                        0
# views                       0
# likes                       0
# dislikes                    0
# comment_count               0
# thumbnail_link              0
# comments_disabled           0
# ratings_disabled            0
# video_error_or_removed      0
# description               570
# dtype: int64

# %%
# prompt: write me a code to predict the null and missing values in row and columns

# Check for missing values
missing_values = df.isnull().sum()
print("Missing values per column:\n", missing_values)

# Check for null values
null_values = df.isnull().sum()
print("\nNull values per column:\n", null_values)

# Find rows with missing values
rows_with_missing_values = df[df.isnull().any(axis=1)]
print("\nRows with missing values:\n", rows_with_missing_values)
# Out:
# Missing values per column:
#  video_id                     0
# trending_date                0
# title                        0
# channel_title                0
# category_id                  0
# publish_time                 0
# tags                         0
# views                        0
# likes                        0
# dislikes                     0
# comment_count                0
# thumbnail_link               0
# comments_disabled            0
# ratings_disabled             0
# video_error_or_removed       0
# description               1296
# dtype: int64
#
# Null values per column:
#  video_id                     0
# trending_date                0
# title                        0
# channel_title                0
# category_id                  0
# publish_time                 0
# tags                         0
# views                        0
# likes                        0
# dislikes                     0
# comment_count                0
# thumbnail_link               0
# ...

# %%
# prompt: write me a code to predict the null and missing values in row and columns

# Check for missing values
missing_values = df1.isnull().sum()
print("Missing values per column:\n", missing_values)

# Check for null values
null_values = df1.isnull().sum()
print("\nNull values per column:\n", null_values)

# Find rows with missing values
rows_with_missing_values = df1[df1.isnull().any(axis=1)]
print("\nRows with missing values:\n", rows_with_missing_values)
# Out:
# Missing values per column:
#  video_id                    0
# trending_date               0
# title                       0
# channel_title               0
# category_id                 0
# publish_time                0
# tags                        0
# views                       0
# likes                       0
# dislikes                    0
# comment_count               0
# thumbnail_link              0
# comments_disabled           0
# ratings_disabled            0
# video_error_or_removed      0
# description               570
# dtype: int64
#
# Null values per column:
#  video_id                    0
# trending_date               0
# title                       0
# channel_title               0
# category_id                 0
# publish_time                0
# tags                        0
# views                       0
# likes                       0
# dislikes                    0
# comment_count               0
# thumbnail_link              0
# ...

# %%
df.dtypes
# Out:
# video_id                  object
# trending_date             object
# title                     object
# channel_title             object
# category_id                int64
# publish_time              object
# tags                      object
# views                      int64
# likes                      int64
# dislikes                   int64
# comment_count              int64
# thumbnail_link            object
# comments_disabled           bool
# ratings_disabled            bool
# video_error_or_removed      bool
# description               object
# dtype: object

# %%
df1.dtypes
# Out:
# video_id                  object
# trending_date             object
# title                     object
# channel_title             object
# category_id                int64
# publish_time              object
# tags                      object
# views                      int64
# likes                      int64
# dislikes                   int64
# comment_count              int64
# thumbnail_link            object
# comments_disabled           bool
# ratings_disabled            bool
# video_error_or_removed      bool
# description               object
# dtype: object

# %% [markdown]
# # **Visualization**
# **Feature Understanding**

# %%
import pandas as pd
from matplotlib import pyplot as plt

# Assuming 'df' is your DataFrame with the YouTube video statistics
# Replace the sample DataFrame with the actual data
# Plot the 'views' column
df['views'].plot(kind='line', figsize=(8, 4), title='YouTube Video Views Trend')
plt.xlabel('Index')  # Set x-axis label
plt.ylabel('Views')  # Set y-axis label
plt.grid(True)  # Enable gridlines
plt.gca().spines[['top', 'right']].set_visible(False)  # Hide top and right spines
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt

# Assuming 'df' is your DataFrame with the YouTube video statistics
# Replace the sample DataFrame with the actual data
# Plot the 'views' column
df1['views'].plot(kind='line', figsize=(8, 4), title='YouTube Video Views Trend')
plt.xlabel('Index')  # Set x-axis label
plt.ylabel('Views')  # Set y-axis label
plt.grid(True)  # Enable gridlines
plt.gca().spines[['top', 'right']].set_visible(False)  # Hide top and right spines
plt.show()

# %%
#Scatter Plot: Relationship between Views and Likes
import matplotlib.pyplot as plt
import seaborn as sns

# Scatter plot: Views vs Likes
plt.figure(figsize=(10, 6))
sns.scatterplot(x='views', y='likes', data=df)
plt.title('Relationship between Views and Likes')
plt.xlabel('Views')
plt.ylabel('Likes')
plt.grid(True)
plt.show()

# %%
#Box Plot: Distribution of Views across Categories
plt.figure(figsize=(10, 6))
sns.boxplot(x='category_id', y='views', data=df)
plt.title('Distribution of Views by Category')
plt.xlabel('Category ID')
plt.ylabel('Views')
plt.show()

# %%
# Check available columns in the DataFrame
print("Available columns in the DataFrame:", df.columns)
# Out:
# Available columns in the DataFrame: Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
#Heatmap: Correlation between Variables
plt.figure(figsize=(8, 6))
sns.heatmap(df[['views', 'likes', 'dislikes', 'comment_count']].corr(), annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Heatmap')
plt.show()

# %%
#Pair Plot: Relationships between Views, Likes, Dislikes, and Comment Count
sns.pairplot(df[['views', 'likes', 'dislikes', 'comment_count']])
plt.suptitle('Pairwise Relationships', y=1.02)
plt.show()

# %%
#Line Plot: Views over Time
# Convert 'publish_time' to datetime if it's not already
df['publish_time'] = pd.to_datetime(df['publish_time'])

# Sort by publish time to ensure the time series is accurate
df = df.sort_values(by='publish_time')

# Line plot: Views over time
plt.figure(figsize=(10, 6))
plt.plot(df['publish_time'], df['views'], marker='o')
plt.title('Views Over Time')
plt.xlabel('Publish Time')
plt.ylabel('Views')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# # **Machine learning'**

# %%
import pandas as pd

# Load your dataset
# df = pd.read_csv('your_dataset.csv')  # Uncomment and provide the path to your dataset

# Display the first few rows of the DataFrame
print(df.head())

# Check for missing values
print(df.isnull().sum())

# Fill or drop missing values as needed
df.fillna(0, inplace=True)  # Example: fill missing values with 0
# Out:
#           video_id trending_date                                    title  \
# 12443  hTSAyR3nOR0      18.17.01  Dolores O'riordan - her house in Canada
# 12685  hTSAyR3nOR0      18.18.01  Dolores O'riordan - her house in Canada
# 4585   rrkW65P-5sc      17.06.12                                  DAY MAN
# 4230   rrkW65P-5sc      17.05.12                                  DAY MAN
# 4014   rrkW65P-5sc      17.04.12                                  DAY MAN
#
#       channel_title  category_id              publish_time  \
# 12443    nenuostabu           10 2008-01-13 01:32:16+00:00
# 12685    nenuostabu           10 2008-01-13 01:32:16+00:00
# 4585      lbisurfer           23 2008-02-12 20:26:00+00:00
# 4230      lbisurfer           23 2008-02-12 20:26:00+00:00
# 4014      lbisurfer           23 2008-02-12 20:26:00+00:00
#
#                                                     tags   views  likes  \
# 12443  dolores|"o'riordan"|"house"|"canada"|"artist"|...  469232   1315
# ...

# %%
# Convert categorical features to numerical
df = pd.get_dummies(df, columns=['category_id'], drop_first=True)

# Select features and target variable
X = df[['views', 'dislikes', 'comments_disabled']]  # Example features
y = df['likes']  # Target variable

# %%
from sklearn.model_selection import train_test_split

# Split data into training and testing sets (70% train, 30% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Create and train the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions using the test set
y_pred = model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r_squared = r2_score(y_test, y_pred)

print(f'Mean Squared Error: {mse:.2f}')
print(f'R-squared: {r_squared:.2f}')
# Out:
# Mean Squared Error: 5594448100.42
# R-squared: 0.68

# %%
import matplotlib.pyplot as plt

# Plot the actual vs. predicted likes
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, label='Predicted Likes', color='red', alpha=0.6)
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'k--', lw=2)  # Diagonal line
plt.title('Actual vs. Predicted Likes')
plt.xlabel('Actual Likes')
plt.ylabel('Predicted Likes')
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor

# Create and train the random forest model
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)

# Make predictions
rf_y_pred = rf_model.predict(X_test)

# Evaluate the model
rf_mse = mean_squared_error(y_test, rf_y_pred)
rf_r_squared = r2_score(y_test, rf_y_pred)

print(f'Random Forest Mean Squared Error: {rf_mse:.2f}')
print(f'Random Forest R-squared: {rf_r_squared:.2f}')
# Out:
# Random Forest Mean Squared Error: 4508314078.73
# Random Forest R-squared: 0.75

# %%
#Prediction: Linear Regression Model to Predict Likes Based on Views
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# Prepare data for prediction
X = df[['views']]
y = df['likes']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Create and train the model
model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Plot the prediction
plt.figure(figsize=(10, 6))
plt.scatter(X_test, y_test, label='Actual Likes', color='blue')
plt.scatter(X_test, y_pred, label='Predicted Likes', color='red', marker='x')
plt.title('Actual vs Predicted Likes based on Views')
plt.xlabel('Views')
plt.ylabel('Likes')
plt.legend()
plt.show()

# Display model's performance (R-squared)
r_squared = model.score(X_test, y_test)
print(f'R-squared: {r_squared}')
# Out:
# R-squared: 0.6830170290896869
